# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib

# %%
file_cc = r"C:\Users\joann\OneDrive - University of Twente\Desktop\IRONHACK\CourseWork\Week4\Week4_project\Datasets\D2\df_europe.csv"
file_price = r"C:\Users\joann\OneDrive - University of Twente\Desktop\IRONHACK\CourseWork\Week4\Week4_project\Datasets\D2\df_meat_price.csv"

# %%
file_price = r"C:\Users\joann\OneDrive - University of Twente\Desktop\IRONHACK\CourseWork\Week4\Week4_project\Datasets\D2\df_meat_price.csv"
df_p = pd.read_csv(file_price)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 file_price = r"C:\Users\joann\OneDrive - University of Twente\Desktop\IRONHACK\CourseWork\Week4\Week4_project\Datasets\D2\df_meat_price.csv"
# ----> 2 df_p = pd.read_csv(file_price)
#
# ...

# %% [markdown]
# ### Hypothesis 1: Global Temperature Trend

# %%
df_cc.head()
# Out:
#                   Country      1969      1970      1971      1972      1973  \
# 0                 Albania -0.013000 -0.106000 -0.195000 -0.069000 -0.288000
# 1                 Austria -0.126000 -0.550000 -0.060000  0.103000 -0.033000
# 2                 Belgium  0.159265  0.092181 -0.201079 -0.084309  0.229161
# 3  Bosnia and Herzegovina  0.159265  0.092181 -0.201079 -0.084309  0.229161
# 4                Bulgaria -0.485000  0.205000 -0.139000  0.136000 -0.426000
#
#        1974      1975      1976      1977  ...   2017   2018   2019   2020  \
# 0 -0.139000 -0.211000 -0.683000  0.545000  ...  1.121  2.028  1.675  1.498
# 1  0.314000  0.860000  0.216000  0.499000  ...  1.741  2.524  2.370  2.315
# 2 -0.162937 -0.024091 -0.245553  0.165255  ...  1.731  2.196  2.081  2.572
# 3 -0.162937 -0.024091 -0.245553  0.165255  ...  1.419  2.275  1.987  1.880
# 4 -0.198000  0.390000 -0.838000  0.563000  ...  0.954  2.192  2.112  2.037
#
# ...

# %%
df_cc_h1 = df_cc.groupby("Country").agg

# %%
# Null Hypothesis (H0): There is no significant change in global surface temperatures over the years.

sns.lineplot(df_cc, x = )

# %%
import matplotlib.pyplot as plt

# Filter data for France and Germany
df_fr = df_cc[df_cc['Country'] == 'France']
df_de = df_cc[df_cc['Country'] == 'Germany']

# Set up the figure and axis
plt.figure(figsize=(10, 6))

# Plot temperature trend for France
plt.plot(df_fr.columns[9:], df_fr.iloc[:, 9:].values.flatten(), label='France')

# Plot temperature trend for Germany
plt.plot(df_de.columns[9:], df_de.iloc[:, 9:].values.flatten(), label='Germany')

# Customize the plot
plt.title('Global Temperature Trend (2013-2022) for France and Germany')
plt.xlabel('Year')
plt.ylabel('Surface Temperature Change (°C)')
plt.legend()

# Show plot
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import matplotlib.pyplot as plt
#       3 # Filter data for France and Germany
# ----> 4 df_fr = df_cc[df_cc['Country'] == 'France']
#       5 df_de = df_cc[df_cc['Country'] == 'Germany']
#       7 # Set up the figure and axis
#
# NameError: name 'df_cc' is not defined
